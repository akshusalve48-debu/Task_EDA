# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data Science/dataset/sales Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#          Order Date                        Purchase Address  Month    Sales  \
# 0   12/30/2019 0:01  136 Church St, New York City, NY 10001     12  1700.00
# 1   12/29/2019 7:03     562 2nd St, New York City, NY 10001     12   600.00
# 2  12/12/2019 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3  12/22/2019 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4  12/18/2019 12:38           43 Hill St, Atlanta, GA 30301     12    11.95
#
#              City  Hour
# 0   New York City   NaN
# 1   New York City   7.0
# 2   New York City  18.0
# 3   San Francisco  15.0
# 4         Atlanta  12.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  object
#  6   Purchase Address  185950 non-null  object
#  7   Month             185950 non-null  int64
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  Hour              185944 non-null  float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 15.6+ MB

# %%
df.shape
# Out:
# (185950, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Order ID', 'Product', 'Quantity Ordered', 'Price Each',
#        'Order Date', 'Purchase Address', 'Month', 'Sales', 'City', 'Hour'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# Sales               float64
# City                 object
# Hour                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                6
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.describe()
# Out:
#           Unnamed: 0       Order ID  Quantity Ordered     Price Each  \
# count  185950.000000  185950.000000     185950.000000  185950.000000
# mean     8340.388475  230417.569379          1.124383     184.399735
# std      5450.554093   51512.737110          0.442793     332.731330
# min         0.000000  141234.000000          1.000000       2.990000
# 25%      3894.000000  185831.250000          1.000000      11.950000
# 50%      7786.000000  230367.500000          1.000000      14.950000
# 75%     11872.000000  275035.750000          1.000000     150.000000
# max     25116.000000  319670.000000          9.000000    1700.000000
#
#                Month          Sales           Hour
# count  185950.000000  185950.000000  185950.000000
# mean        7.059140     185.490917      14.413770
# std         3.502996     332.919771       5.422798
# min         1.000000       2.990000       0.000000
# 25%         4.000000      11.950000      11.000000
# 50%         7.000000      14.950000      15.000000
# 75%        10.000000     150.000000      19.000000
# max        12.000000    3400.000000      23.000000

# %%
plt.hist(df['Sales'], bins=20)
plt.title("Sales Distribution")
plt.show()

# %%
sns.boxplot(x=df['Sales'])
plt.show()

# %%
correlation = df.corr(numeric_only=True)

print(correlation)
# Out:
#                   Unnamed: 0  Order ID  Quantity Ordered  Price Each  \
# Unnamed: 0          1.000000  0.357507         -0.003133    0.001471
# Order ID            0.357507  1.000000          0.000702   -0.002857
# Quantity Ordered   -0.003133  0.000702          1.000000   -0.148272
# Price Each          0.001471 -0.002857         -0.148272    1.000000
# Month               0.266516  0.993063          0.000791   -0.003375
# Sales               0.001373 -0.002949         -0.139417    0.999203
# Hour               -0.001005  0.001284         -0.002242    0.001760
#
#                      Month     Sales      Hour
# Unnamed: 0        0.266516  0.001373 -0.001005
# Order ID          0.993063 -0.002949  0.001284
# Quantity Ordered  0.000791 -0.139417 -0.002242
# Price Each       -0.003375  0.999203  0.001760
# Month             1.000000 -0.003466  0.001852
# Sales            -0.003466  1.000000  0.001707
# Hour              0.001852  0.001707  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation,
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %%
category_sales = df.groupby('Month')['Sales'].sum()

category_sales.plot(kind='bar')

plt.title("Sales by month")
plt.show()
